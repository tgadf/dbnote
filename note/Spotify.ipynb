# %%
# %load_ext autoreload
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from dbmaster import MasterParams, MasterPersist
from dbbase import MusicDBIDModVal, MusicDBDir, MusicDBData
from dbnote import DownloadRecord, MergeSearchArtist
from utils import FileIO, DirInfo, FileInfo, getFlatList, Timestat, TermTime, TermTimeTS, getTT
from pandas import Series, DataFrame, concat, Timestamp
from pandb import PanDBIO
from musicdb.spotify import MusicDBParams, RawAPIData, MusicDBIO
from os import getpid
from functools import partial

mv = MusicDBIDModVal()
io = FileIO()
mpar = MusicDBParams()
dbio = MusicDBIO()
apiio = RawAPIData()
db = mpar.db

# %%
searchArtistRecord = DownloadRecord(db=db, name="SearchArtist", rTypes=["Index", "Data"])
downloadArtistRecord = DownloadRecord(db=db, name="DownloadArtist", rTypes=["Index"])
downloadArtistAlbumRecord = DownloadRecord(db=db, name="DownloadArtistAlbum", rTypes=["Index"])
downloadArtistTrackRecord = DownloadRecord(db=db, name="DownloadArtistTrack", rTypes=["Index"])
downloadArtistRelRecord = DownloadRecord(db=db, name="DownloadArtistRel", rTypes=["Index"])
downloadArtistIDRecord = DownloadRecord(db=db, name="DownloadArtistID", rTypes=["Index"])
downloadTrackRecord = DownloadRecord(db=db, name="DownloadTrack", rTypes=["Index"])
knownArtists = dbio.rdio.getSummaryNameData
allArtists = partial(dbio.rdio.getData, "SearchArtist")
# Out:
# DownloadRecord(db=Spotify, name=SearchArtist, rTypes=['Index', 'Data'])
# DownloadRecord(db=Spotify, name=DownloadArtist, rTypes=['Index'])
# DownloadRecord(db=Spotify, name=DownloadArtistAlbum, rTypes=['Index'])
# DownloadRecord(db=Spotify, name=DownloadArtistTrack, rTypes=['Index'])
# DownloadRecord(db=Spotify, name=DownloadArtistRel, rTypes=['Index'])
# DownloadRecord(db=Spotify, name=DownloadArtistID, rTypes=['Index'])
# DownloadRecord(db=Spotify, name=DownloadTrack, rTypes=['Index'])

# %%
if False:
    from utils import FileInfo
    import shutil
    db = dbio.params.db
    dbdir = dbio.params.dir
    nameMap = {"MasterArtists": "SearchArtist", "LocalArtists": "DownloadArtist", "LocalTracks": "DownloadTrack"}
    nameMap = nameMap | {"LocalArtistTracks": "DownloadArtistTrack", "LocalArtistAlbums": "DownloadArtistAlbum",
                         "LocalArtistSimilar": "DownloadArtistSimilar", "LocalGenres": "DownloadGenre",
                         "LocalArtistRels": "DownloadArtistRel", "LocalArtistIDs": "DownloadArtistID"}
    dinfo = DirInfo(f"/Users/tgadfort/anaconda3/envs/post/pandb/musicdb/{db}")
    
    cpMap = {}
    for origname, newname in nameMap.items():
        cpMap[f"{dbdir}SearchedFor{origname}"] = f"{db}-{newname}-Index"
        cpMap[f"{dbdir}SearchedFor{origname}Data"] = f"{db}-{newname}-Data"
        cpMap[f"{dbdir}SearchedFor{origname}Errors"] = f"{db}-{newname}-Error"
    assert dinfo.exists(), f"{dinfo} does not exist!"
    for srcFile, dstFile in cpMap.items():
        srcFile = dinfo.join(f"{srcFile}.p")
        dstFile = dinfo.join(f"{dstFile}.p")
        if srcFile.exists():
            srcFile.mvFile(dstFile)

# %%
##########################################################################################
# Show Summary
##########################################################################################
print(f"{db} Search Results (PID={getpid()})".format(db))
searchArtistRecord.info()
downloadArtistRecord.info()
downloadArtistAlbumRecord.info()
downloadArtistTrackRecord.info()
downloadArtistRelRecord.info()
downloadArtistRecord.info()
downloadArtistIDRecord.info()
downloadTrackRecord.info()
print(f"  {'KnownArtist Data': <20}: {knownArtists().shape[0]}")

# %% [markdown]
# # Search For New Artists

# %%
######################################################################################################
# Explode Recent Data
######################################################################################################
def getNewData(searchArtistRecord):
    newData = searchArtistRecord.getData()
    if len(newData) == 0:
        return DataFrame()
    newData = concat([DataFrame(s).T for s in newData.values()])
    newData.index = newData.index.astype(str)
    newData = newData[~newData.index.duplicated()].drop("sid", axis=1)
    return newData

def mergeNewData(searchArtistRecord):
    searchArtistRecord.load(verbose=False)
    newData = getNewData(searchArtistRecord)
    msr = MergeSearchArtist(db)
    msr.mergeLocal(searchArtistRecord, newData, test=False)

# %%
dbio = MusicDBIO(verbose=False,local=True,mkDirs=False)
apiio = RawAPIData(debug=False)
knownNames = PanDBIO().getUniqueArtistNames()
mergeNewData(searchArtistRecord)
searchedNames = Series(searchArtistRecord.getIndex())
artistNamesToGet = knownNames[~knownNames.map(searchArtistRecord.isKnown)]

print(f"# {db} Search Results (PID={getpid()})")
print(f"#   Available Names:     {knownNames.shape[0]}")
print(f"#   Known Artist Names:  {searchedNames.shape[0]}")
print(f"#   Artist Names To Get: {artistNamesToGet.shape[0]}")

del searchedNames
del knownNames

# %%
ts = Timestat(f"Getting {db} ArtistIDs")
tt = getTT(skipEOD=False, vacation=True)
assert dbio.rdio.isLocal, f"MusicDBIO is not set for local downloads!"

def isError(artistName, nErrors, sleeptime, error=None):
    searchArtistRecord.setError(index=artistName)
    print(f"Search Error ==> {artistName}: {error}")
    nErrors.append(artistName)
    apiio.sleep(sleeptime)
    
n = 0
maxN = 250000000
nErrors = []
searchArtistRecord.load(verbose=False)
for i, (idx, artistName) in enumerate(artistNamesToGet.items()):
    if searchArtistRecord.isKnown(artistName):
        continue

    if len(nErrors) >= 5:
        print("Stopping due to 5 consecutive errors")
        break

    try:
        response = apiio.getArtistSearchData(artistName=artistName)
    except Exception as error:
        isError(artistName, nErrors, 10, error)
        continue

    if not isinstance(response, dict):
        isError(artistName, nErrors, 3.5, "NotDict")
        continue

    nErrors = []
    searchArtistRecord.setData(index=artistName, data=response)
    apiio.sleep(2.5)
    n += 1
        
    if n % 5 == 0:
        if tt.isFinished():
            break
        apiio.sleep(1.0)
        
    if n % 100 == 0:
        ts.update(n=n)
        searchArtistRecord.save()
        apiio.wait(10.0)
        if tt.isFinished():
            break
    
    if n >= maxN:
        print(f"Breaking after {maxN} downloads...")
        break

ts.stop()
searchArtistRecord.save()

# %%
searchArtistRecord.save()

# %%
msa = MergeSearchArtist("RateYourMusic")
msa.copyFromLocal(force=True)
# Out:
# *****************************************************************************************************************************
# *                                            MergeSearchArtist(db=RateYourMusic)                                            *
# *****************************************************************************************************************************
# Old Global Shape: (584812, 2)
# New Local Shape:  (643810, 2)
# New Global Shape: (643810, 2)

# %%
from dbnote import backup
backup("RateYourMusic", doMod=False, doSearch=True)
# Out:
# ****************************************************************************************************
# *                                     Backing Up RateYourMusic                                     *
# ****************************************************************************************************
#  [Backing Up Raw RateYourMusic Data] | StartTime 2023-12-05 14:11:24
#  [Backing Up Raw RateYourMusic Data] | ?/?        : RunTime .  >> Checking Raw Path [/Volumes/Piggy/Discog/artists-rateyourmusic] <<
#  [Backing Up Raw RateYourMusic Data] | ?/?        : RunTime .  >> Checking Mod Path [/Volumes/Seagate/Discog/artists-rateyourmusic] <<
# ***************************************************************************************************
# *                                           ModVal Data                                           *
# ***************************************************************************************************
# Not checking the raw mod path
# ***************************************************************************************************
# *                                           Search Data                                           *
# ***************************************************************************************************
# subprocess.call ===> ['rsync', '-azh', '/Volumes/Piggy/Discog/artists-rateyourmusic/search', '/Volumes/Seagate/Discog/artists-rateyourmusic']
#  [Backing Up Raw RateYourMusic Data] | RunTime 19 Second.  2023-12-05 14:11:43

# %% [markdown]
# # Download Artist Albums Data

# %%
dbio = MusicDBIO(verbose=False,local=True,mkDirs=False)
apiio = RawAPIData(debug=False)
knownNames = allArtists()[['name']]
knownNames['ModVal'] = knownNames.index.map(mv.getModVal)
availableNames = knownNames[~knownNames.index.map(downloadArtistAlbumRecord.isKnown)]
artistNamesToGet = Series({modVal: modValDF for modVal,modValDF in availableNames.groupby("ModVal")})

print(f"# {db} Search Results")
print(f"#   Available Names:     {knownNames.shape[0]}")
print(f"#   Known Artist Names:  {downloadArtistAlbumRecord.numKnown()}")
print(f"#   Artist Names To Get: {availableNames.shape[0]}")

del availableNames
del knownNames
# Out:
# # Spotify Search Results
# #   Available Names:     5149586
# #   Known Artist Names:  2435291
# #   Artist Names To Get: 2714562

# %%
ts = Timestat(f"Getting {db} ArtistIDs")
tt = getTT(skipEOD=False, vacation=True)
assert dbio.rdio.isLocal, f"MusicDBIO is not set for local downloads!"

def isError(artistName, artistID, nErrors, sleeptime, error=None):
    downloadArtistAlbumRecord.setError(index=artistID)
    print(f"Search Error ==> {artistName}: {error}")
    nErrors.append(artistName)
    apiio.sleep(sleeptime)
    
n = 0
maxN = 2500000
stop = False
nErrors = []
#downloadArtistAlbumRecord.load()
for groupModVal,modValData in artistNamesToGet.items():
    if stop is True:
        break
    modVal = groupModVal
    N = modValData.shape[0]
    for i,(artistID, artistName) in enumerate(modValData['name'].items()):    
        if downloadArtistAlbumRecord.isKnown(artistID):
            continue
    
        if len(nErrors) >= 5:
            print("Stopping due to 5 consecutive errors")
            stop = True
            break
    
        print(f"{groupModVal: <3} | {i: <5} | {N: <5} | {n: <5} | ", end="")
        
        try:
            response = apiio.getArtistAlbums(artistID=artistID, artistName=artistName)        
        except Exception as error:
            isError(artistName, artistID, nErrors, 5, error)
            continue
    
        if not isinstance(response, dict):
            isError(artistName, artistID, nErrors, 3.5, "NotDict")
            continue

        
        nErrors = []
        dbio.rdio.saveData("RawArtistAlbum", modVal, artistID, data=response)
        downloadArtistAlbumRecord.setIndex(index=artistID)
        apiio.sleep(2.5)
        n += 1
            
        if n % 5 == 0:
            if tt.isFinished():
                stop = True
                break
            
        if n % 100 == 0:
            ts.update(n=n)
            downloadArtistAlbumRecord.save()
            apiio.wait(15.0)
            if tt.isFinished():
                stop = True
                break
        
        if n >= maxN:
            print(f"Breaking after {maxN} downloads...")
            stop = True
            break

ts.stop()
#downloadArtistAlbumRecord.save()
# Out:
#  [Getting Spotify ArtistIDs] | StartTime 2023-12-05 14:46:18
#    ====> Terminate Time Set To 2023-12-05 19:00:00 <====
#    ====> Will Terminate Process 4 Hour and 13 Minute From Now
# 0   | 0     | 17864 | 0     | Downloading Albums For Khash (1fhZFzqMpeBm31zLIEmSlJ)                       ===> [2] 2  2
# 0   | 1     | 17864 | 1     | Downloading Albums For Kiing Khash (3fuQRvDqG6HBPfqkKyd6PI)                 ===> [1] 1  1
# 0   | 2     | 17864 | 2     | Downloading Albums For Caleb Kelly (5ucGGiixTyCmzDMTYwm0zv)                 ===> [4] 4  4
# 0   | 3     | 17864 | 3     | Downloading Albums For Nizum Eoki (4iGLtY8wYhtQK4LeQFgAiq)                  ===> [1] 1  1
# 0   | 4     | 17864 | 4     | Downloading Albums For Koton (4YkiNg5eTjctAr6dELMRfX)                       ===> [6] 6  6
# 0   | 5     | 17864 | 5     | Downloading Albums For Kolton Caulfield (2zykWMyTPvjYa8OaQpy8QW)            ===> [1] 1  1
# 0   | 6     | 17864 | 6     | Downloading Albums For Rastamen jojo (18DUTN7VRG84xgv4V81G4Y)               ===> [23] 23  23
# 0   | 7     | 17864 | 7     | Downloading Albums For T.i.d Midas (5SBhP8L3kUyL48mM36NOOJ)                 ===> [1] 1  1
# 0   | 8     | 17864 | 8     | Downloading Albums For 10X (4Dm8GgbaqWzgnZeZrxAW0R)                         ===> [18] 18  18
# 0   | 9     | 17864 | 9     | Downloading Albums For TreeOnDaSlap (6wiC8U3OKNgw8IHmojgxfk)                ===> [1] 1  1
# 0   | 10    | 17864 | 10    | Downloading Albums For Verde Bicicleta (0RVVDIuLfXMSMV1Pgc8hh3)             ===> [7] 7  7
# 0   | 11    | 17864 | 11    | Downloading Albums For Eddie Rocket (1pHLGUErNvV6PPC8Yz5pcH)                ===> [16] 16  16
# 0   | 12    | 17864 | 12    | Downloading Albums For Anthony Stango (17d4IjOFsfWsWaIvf1DCWM)              ===> [16] 16  16
# 0   | 13    | 17864 | 13    | Downloading Albums For Ant Youngin (5d8Icjng2Q2F6MVplrN4rH)                 ===> [1] 1  1
# 0   | 14    | 17864 | 14    | Downloading Albums For Kubusiowy (6vRPHBrVcsoxG3fVw8o6EQ)                   ===> [13] 13  13
# 0   | 15    | 17864 | 15    | Downloading Albums For tiyes romantic project (5Ew9a37Stq0k9So7HRhwyZ)      ===> [3] 3  3
# 0   | 16    | 17864 | 16    | Downloading Albums For Kirsten Reinhardt (4uAKhLO452qYVB5e4FYiyp)           ===> [1] 1  1
# 0   | 17    | 17864 | 17    | Downloading Albums For Melissa Norelli (6LZIXVZwNW08VbZBcYTTyD)             ===> [1] 1  1
# 0   | 18    | 17864 | 18    | Downloading Albums For Vulture (0lodBfC88zIOmMCn7kuAtX)                     ===> [2] 2  2
# 0   | 19    | 17864 | 19    | Downloading Albums For Marian Schwab (4qmdz4ccdBdXKSLPZ8Ymg0)               ===> [1] 1  1
# 0   | 20    | 17864 | 20    | Downloading Albums For Rikki + Angel Cortez (4cUVOscCO5VO2ghbFyZkfB)        ===> [3] 3  3
# 0   | 21    | 17864 | 21    | Downloading Albums For MASTER MENDOZA J.i (65dwMLUb9OfM4r3ftn8nuU)          ===> [3] 3  3
# 0   | 22    | 17864 | 22    | Downloading Albums For Axel (6ghXsDVPn42hEKGnqB1Krn)                        ===> [8] 8  8
# 0   | 23    | 17864 | 23    | Downloading Albums For Siggerr (0lwQIZf6i33MfwXgymtF3n)                     ===> [10] 10  10
# 0   | 24    | 17864 | 24    | Downloading Albums For LUDEN (2Ol6gmG442tBcnfORwcQsU)                       ===> [10] 10  10
# 0   | 25    | 17864 | 25    | Downloading Albums For Jordi (5ZTJEC2UH1RXQT9K1mDCJ3)                       ===> [5] 5  5
# 0   | 26    | 17864 | 26    | Downloading Albums For TAU (BW) (4M43WLHD3zKA8Pe9XMpRPk)                    ===> [9] 9  9
# 0   | 27    | 17864 | 27    | Downloading Albums For Lofi Light (35gHBFothUwqXzORPTrlBU)                  ===> [14] 14  14
# 0   | 28    | 17864 | 28    | Downloading Albums For graxx.xx (0tj1xiCcgKrSp1svtLVqGA)                    ===> [0] 0  0
# 0   | 29    | 17864 | 29    | Downloading Albums For water (7pB869Ran7FOoiGG7SpXxu)                       ===> [15] 15  15
# 0   | 30    | 17864 | 30    | Downloading Albums For Christian Horseback (0gPtsiAEYlNI6iGbOWtKnJ)         ===> [1] 1  1
# 0   | 31    | 17864 | 31    | Downloading Albums For Maya (7uFfPGa0fpMnqUesobO0lt)                        ===> [2] 2  2
# 0   | 32    | 17864 | 32    | Downloading Albums For 44klip (44lDivLGI9OojNd44n4gY6)                      ===> [8] 8  8
# 0   | 33    | 17864 | 33    | Downloading Albums For AlexVorn (3C7dPxpUfCrDy9uU7peNEG)                    ===> [8] 8  8
# 0   | 34    | 17864 | 34    | Downloading Albums For Midave (6rkBcViDFrVHcJyPepQ0f7)                      ===> [1] 1  1
# 0   | 35    | 17864 | 35    | Downloading Albums For Ron de Lauren (5P9IE3snjc1rSoMKPIjzod)               ===> [6] 6  6
# 0   | 36    | 17864 | 36    | Downloading Albums For OG Dre La Hoya (6Oyivc1jOeiqCk8coWDtkv)              ===> [2] 2  2
# 0   | 37    | 17864 | 37    | Downloading Albums For Christy Air (14Lxjop4dsljOyzST7lqxp)                 ===> [1] 1  1
# 0   | 38    | 17864 | 38    | Downloading Albums For Trinidad La Bruja (1pddptPolyxZ7fZFt0NI2F)           ===> [1] 1  1
# 0   | 39    | 17864 | 39    | Downloading Albums For Karla Cristina y La Trinidad (1LzdpotUqq3T2fRBEHBVhG)   ===> [1] 1  1
# 0   | 40    | 17864 | 40    | Downloading Albums For สำนักการสังคีตกรมศิลปากร (5fw9X60n7PZEty6J6fbKiT)    ===> [12] 12  12
# 0   | 41    | 17864 | 41    | Downloading Albums For Roblox Songs By Supatra & Lung$ (0R3EMHU1oYyKnffbClZdDX)   ===> [9] 9  9
# 0   | 42    | 17864 | 42    | Downloading Albums For Grupo RDN (1IZh6La0UpfajILznjR61Q)                   ===> [4] 4  4
# 0   | 43    | 17864 | 43    | Downloading Albums For Urban Latin DJ's (41ZgAaZP94MxspGvHyi8iA)            ===> [22] 22  22
# 0   | 44    | 17864 | 44    | Downloading Albums For Andrea Hegard (3MmOz5vBJnUbJ2MhBLzcvl)               ===> [4] 4  4
# 0   | 45    | 17864 | 45    | Downloading Albums For Voxish (3sqrnw6YtnYprPAh767V8o)                      ===> [6] 6  6
# 0   | 46    | 17864 | 46    | Downloading Albums For VITALY (0yqk3GPt6uBe7W9NdbVeHZ)                      ===> [7] 7  7
# 0   | 47    | 17864 | 47    | Downloading Albums For Kami Kamikaze (7vFzb4BpBJj6IbvrMlXOHq)               ===> [10] 10  10
# 0   | 48    | 17864 | 48    | Downloading Albums For YEAH BOY (2oCpOhDILPc1f6UBRtFXbT)                    ===> [4] 4  4
# 0   | 49    | 17864 | 49    | Downloading Albums For 睡眠音楽ラボ (2NOhoEzoSgTLriz2sorUWv)                      ===> [1] 1  1
# 0   | 50    | 17864 | 50    | Downloading Albums For Chorus & Orchestra of La Scala, Milan (036NjyPMhwol1tHl7V7Jqq)   ===> [1] 1  1
# 0   | 51    | 17864 | 51    | Downloading Albums For Linnea Lomholt (6Ka5mXpKtgOr6QFOXNDVuV)              ===> [4] 4  4
# 0   | 52    | 17864 | 52    | Downloading Albums For Renée Ruth (1SS5i0AUikRmcMf9VP06Uy)                  ===> [12] 12  12
# 0   | 53    | 17864 | 53    | Downloading Albums For Element in One (3j7tma2AzV1FLqjPd5E5e5)              ===> [2] 2  2
# 0   | 54    | 17864 | 54    | Downloading Albums For Leandro Loza (0xxImgih9pB8nDxX0LLLon)                ===> [9] 9  9
# 0   | 55    | 17864 | 55    | Downloading Albums For Zach Affolter (3cUIR37UWGRe6dBkyZx6xW)               ===> [11] 11  11
# 0   | 56    | 17864 | 56    | Downloading Albums For ZAROK LA LEALTAD (7IrUgaewMWpvkYUsOm96mG)            ===> [10] 10  10
# 0   | 57    | 17864 | 57    | Downloading Albums For Jonny Starseed (5JNtYvA3sCak28TeXIQcWi)              ===> [21] 21  21
# 0   | 58    | 17864 | 58    | Downloading Albums For Nature Sounds Academy (0xOcy2fixSe2T0NvKNLmiK)       ===> [14] 14  14
# 0   | 59    | 17864 | 59    | Downloading Albums For William Cistone (3ft2t1HSanjyn2gVRPetfm)             ===> [1] 1  1
# 0   | 60    | 17864 | 60    | Downloading Albums For Dinner Jazz Background Music (2nO52SyrgiDqINEQt6R8oQ)   ===> [50] 50  50
# 0   | 61    | 17864 | 61    | Downloading Albums For Sam García (4VtZxSt4aNiQC4hhardU3g)                  ===> [4] 4  4
# 0   | 62    | 17864 | 62    | Downloading Albums For Early Rosegold (7IxwtTkTv3x3gwWqrYZaPW)              ===> [1] 1  1
# 0   | 63    | 17864 | 63    | Downloading Albums For David Brent (789mWYbGRgczL0pYyxh3SG)                 ===> [5] 5  5
# 0   | 64    | 17864 | 64    | Downloading Albums For Falton (0eQCgYy3Uc4CuWDe885WAo)                      ===> [2] 2  2
# 0   | 65    | 17864 | 65    | Downloading Albums For Carlos Carpenter (6x9pLMFwxLKszDvJixBRuB)            ===> [2] 2  2
# 0   | 66    | 17864 | 66    | Downloading Albums For Dj Red-i (3zrXUJP8VeuyepdeBQ9hsl)                    ===> [8] 8  8
# 0   | 67    | 17864 | 67    | Downloading Albums For SAPA13 (2ZzErTHRFaauCCr6cev4fg)                      ===> [33] 33  33
# 0   | 68    | 17864 | 68    | Downloading Albums For Aykan Emir (31NNLCMZoYH1tkwABGaka1)                  ===> [17] 17  17
# 0   | 69    | 17864 | 69    | Downloading Albums For RG MC (6nUNnipReE1C5sAwC5H0mM)                       ===> [1] 1  1
# 0   | 70    | 17864 | 70    | Downloading Albums For Hugo23 (2gecM55XIWyU2dlWMcga9b)                      ===> [47] 47  47
# 0   | 71    | 17864 | 71    | Downloading Albums For Jarrett Beeler (5Lkgoec7QTJ0t2t9CtK7s6)              ===> [4] 4  4
# 0   | 72    | 17864 | 72    | Downloading Albums For Joymin (3KsGWj5GhKDDvU0pCGn5gP)                      ===> [6] 6  6
# 0   | 73    | 17864 | 73    | Downloading Albums For Jocelynn (33CpSsAbCucUKIJ8nrgdXv)                    ===> [1] 1  1
# 0   | 74    | 17864 | 74    | Downloading Albums For Connor Mac (6Bi2tsl1vcWt1mh7H4rBMH)                  ===> [1] 1  1
# 0   | 75    | 17864 | 75    | Downloading Albums For Aled Woods (0wKTGMsgUn3cMfCoIzJ6yK)                  ===> [1] 1  1
# 0   | 76    | 17864 | 76    | Downloading Albums For Water Seed (5Urzj24qvnjUNQByIFPNTL)                  ===> [27] 27  27
# 0   | 77    | 17864 | 77    | Downloading Albums For CoLLTure (0sH0m3UoC81z0hQCU2tdJN)                    ===> [8] 8  8
# 0   | 78    | 17864 | 78    | Downloading Albums For Deborah Luman (6ECfTOwRS9QkTKgziQ5BBO)               ===> [0] 0  0
# 0   | 79    | 17864 | 79    | Downloading Albums For Rich Ray (2DZYdjYz0MMYLNsnBVxeEM)                    ===> [1] 1  1
# 0   | 80    | 17864 | 80    | Downloading Albums For HOTBOIIYAYA (4qpbyQ81lgSmEpiUVNK68t)                 ===> [30] 30  30
# 0   | 81    | 17864 | 81    | Downloading Albums For Studio 90 (34miJHXsoBMeaJsw6ciCJy)                   ===> [12] 12  12
# 0   | 82    | 17864 | 82    | Downloading Albums For BadGuy Skatt (4A9KntQlKWXLhYbRiQl9sb)                ===> [2] 2  2
# 0   | 83    | 17864 | 83    | Downloading Albums For BADCLAUSE (0Pouk1qst9zy69Sn81D65h)                   ===> [22] 22  22
# 0   | 84    | 17864 | 84    | Downloading Albums For Nikita Lev (6Dsxdy9Skdir5MqifGmf6c)                  ===> [5] 5  5
# 0   | 85    | 17864 | 85    | Downloading Albums For Josef Martin (3lxB0KR48ioggRQjB62HOJ)                ===> [1] 1  1
# 0   | 86    | 17864 | 86    | Downloading Albums For Rico Ruffbeats (3CMuhychFjOU6OVceC5LBG)              ===> [34] 34  34
# 0   | 87    | 17864 | 87    | Downloading Albums For Max Bustos (1Ge0bFQhOHJALV5gqM23qy)                  ===> [12] 12  12
# 0   | 88    | 17864 | 88    | Downloading Albums For Chuckyy (0HRGx78eQaMqoHoopLfi2h)                     ===> [8] 8  8
# 0   | 89    | 17864 | 89    | Downloading Albums For Sic Mic (7LFapeOZ3AQKB2CMr5l8C9)                     ===> [1] 1  1
# 0   | 90    | 17864 | 90    | Downloading Albums For Sick Mick (5Uu2vHxAjz9EWDrAZkq2sl)                   ===> [1] 1  1
# 0   | 91    | 17864 | 91    | Downloading Albums For Siccness (4ZBXa8P2Ab3j0PoGFlaVzy)                    ===> [24] 24  24
# 0   | 92    | 17864 | 92    | Downloading Albums For LUC (3aXEFKH6dNXmuS2R4MUiL9)                         ===> [23] 23  23
# 0   | 93    | 17864 | 93    | Downloading Albums For ZAY (2XuPUJnQiMvzPNPaBKoPqO)                         ===> [8] 8  8
# 0   | 94    | 17864 | 94    | Downloading Albums For DAMFO (0kp1Hrfeg7Zew7IfSbcoNs)                       ===> [17] 17  17
# 0   | 95    | 17864 | 95    | Downloading Albums For Music Junkies Official (2XGUiLChwdHab6yeDoljcI)      ===> [1] 1  1
# 0   | 96    | 17864 | 96    | Downloading Albums For Brandon Gwinn (1ABRSs2MNA0ixriOe4YGIR)               ===> [1] 1  1
# 0   | 97    | 17864 | 97    | Downloading Albums For TOPZERO (5QEOq7vruiADekkllAtiX4)                     ===> [1] 1  1
# 0   | 98    | 17864 | 98    | Downloading Albums For Artona-duo klavír a 2 harmoniky (2ZlSvdILeUZgue3NA7TO1M)   ===> [1] 1  1
# 0   | 99    | 17864 | 99    | Downloading Albums For Ken Keather (0DHd7dhpTFNGGUIr7dA5fX)                 ===> [1] 1  1
#  [Getting Spotify ArtistIDs] | 100/?      : RunTime 4 Minute and 27 Second.
# ****************************************************************************************************************************
# *                                                Saving DownloadArtistAlbum                                                *
# ****************************************************************************************************************************
#   Saving Index [2435391] ... Done
#   Saving Error [55] ... Done
# Waiting:   0%|          | 0/150 [00:00<?, ?it/s]
# 0   | 100   | 17864 | 100   | Downloading Albums For Nate Craig (7lwjoqjZA6KNiggqExd0Q5)                  ===> [3] 3  3
# 0   | 101   | 17864 | 101   | Downloading Albums For Ausequa (3EGztqdS3AiRKi6kryRNg1)                     ===> [43] 43  43
# 0   | 102   | 17864 | 102   | Downloading Albums For NUTANA (2IlotRrtfpIKvTZhXoXDH0)                      ===> [3] 3  3
# 0   | 191   | 17864 | 191   | Downloading Albums For Warkane feat Molby Mojo (1OgjsF8SqQG85iKQ0Rynql)     ===> [1] 1  1
# 0   | 192   | 17864 | 192   | Downloading Albums For Nhạc Ngủ Thư Giãn (4Fj7umf3gPhml4CB3oD7v9)           ===> [14] 14  14
# 0   | 193   | 17864 | 193   | Downloading Albums For Spectra Intersperse (49igHWaOZrSPJqXUPkxAbg)         ===> [1] 1  1
# 0   | 194   | 17864 | 194   | Downloading Albums For TheRealKingSimba (0AO3Hik1ozfnsBXYj0JCgu)            ===> [19] 19  19
# 0   | 195   | 17864 | 195   | Downloading Albums For The Nervous Mongoose (1t2lswNA0uoTYgsjYz4kyt)        ===> [3] 3  3
# 0   | 196   | 17864 | 196   | Downloading Albums For Unique Show (18JsjY5dcmwLydRl7WjdXL)                 ===> [1] 1  1
# 0   | 197   | 17864 | 197   | Downloading Albums For Solix (64JFLKvGCiKDTsN0hfjXeI)                       ===> [22] 22  22
# 0   | 198   | 17864 | 198   | Downloading Albums For Signif (0UbAv6e2z6do1sl1u1OciS)                      ===> [12] 12  12
# 0   | 199   | 17864 | 199   | Downloading Albums For TKAY BEATS (5e4NjR5tcG34rKuwFG4O54)                  ===> [1] 1  1
#  [Getting Spotify ArtistIDs] | 200/?      : RunTime 9 Minute and 44 Second.
# ****************************************************************************************************************************
# *                                                Saving DownloadArtistAlbum                                                *
# ****************************************************************************************************************************
#   Saving Index [2435491] ... Done
#   Saving Error [55] ... Done
# Waiting:   0%|          | 0/150 [00:00<?, ?it/s]
# 0   | 200   | 17864 | 200   | Downloading Albums For Leo & Ray (3tdvuW4bIMZwElpiMETwwm)                   ===> [1] 1  1
# 0   | 201   | 17864 | 201   | Downloading Albums For El Noruego (3NoEPAjoWZrCbUEXlUiZxs)                  ===> [6] 6  6
# 0   | 202   | 17864 | 202   | Downloading Albums For Tatiana Marie Clark (2ovAB32IEY5k4Mgdl5eSfq)         ===> [4] 4  4
# 0   | 203   | 17864 | 203   | Downloading Albums For Fabrizio Berlincioni (7EI7G45KH76Fdywj5JhX0h)        ===> [6] 6  6
# 0   | 204   | 17864 | 204   | Downloading Albums For ROBINIO MUNDIBU (2BlWaS37aIC7bfZgdjEBgc)             ===> [1] 1  1
# 0   | 205   | 17864 | 205   | Downloading Albums For Fly Tye (6enisH6pEn6OsLggg4OZ68)                     ===> [24] 24  24
# 0   | 206   | 17864 | 206   | Downloading Albums For Korslagda Kukar (7uW0TRg4ie6mixKsuLEuAv)             ===> [6] 6  6
# 0   | 207   | 17864 | 207   | Downloading Albums For Kira Michele (1sfaaI0Ye2P9IjdVai9api)                ===> [24] 24  24
# 0   | 208   | 17864 | 208   | Downloading Albums For Chun.C (15mhMswt6cv3Wqj1FocgaY)                      ===> [5] 5  5
# 0   | 209   | 17864 | 209   | Downloading Albums For SF GBaby (7ESWGJ04SDU1gsn1rCjbHw)                    ===> [1] 1  1
# 0   | 210   | 17864 | 210   | Downloading Albums For Lord Vito (4LxE3KXSgti3sQLGRubSNQ)                   ===> [6] 6  6
# 0   | 255   | 17864 | 255   | Downloading Albums For Rauls (796ZZfRoOotO1rNuGbBUXG)                       ===> [9] 9  9
# 0   | 256   | 17864 | 256   | Downloading Albums For Raul sd (3DlkVXwwxD5ri8W64qPGuF)                     ===> [0] 0  0
# 0   | 257   | 17864 | 257   | Downloading Albums For Matthis Veeke (5cWdHQe0I5dtUd994gTJLq)               ===> [1] 1  1
# 0   | 258   | 17864 | 258   | Downloading Albums For Piano for Sleep (7uFTzEMpJt1Sx5BX2cvEO3)             ===> [159] 50 .. 122
# 0   | 259   | 17864 | 259   | Downloading Albums For Bill Hare (4Bs0fngqtXm6NtmyfPMmXA)                   ===> [1] 1  1
# 0   | 260   | 17864 | 260   | Downloading Albums For London Television Orchestra (5ZsNYVLPf93JfPCdF9KfEJ)   ===> [10] 10  10
# 0   | 261   | 17864 | 261   | Downloading Albums For Skeli (4cmgvL5mn15IYqkAaj2Y1t)                       ===> [2] 2  2
# 0   | 262   | 17864 | 262   | Downloading Albums For Nature Sounds Prime (2qoc10ctseHzTxkw3b8PDO)         ===> [10] 10  10
# 0   | 263   | 17864 | 263   | Downloading Albums For Young Dizz (1Hfv6QEyAKm3aISDfdJ8TW)                  ===> [8] 8  8
# 0   | 264   | 17864 | 264   | Downloading Albums For Grupo Culminante (3L3udyAFXAieFPjf3xjUOT)            ===> [2] 2  2
# 0   | 265   | 17864 | 265   | Downloading Albums For Culath (4Oj680OAqJCesXZBcK0oOj)                      ===> [3] 3  3
# 0   | 266   | 17864 | 266   | Downloading Albums For AuriSwan (4tpbStm7cWw5ZpaIu3Lz8B)                    ===> [2] 2  2
# 0   | 267   | 17864 | 267   | Downloading Albums For Treisforreal (2w1PuvIewLzUW9emEEpqiG)                ===> [1] 1  1
# 0   | 268   | 17864 | 268   | Downloading Albums For Jean Hampel (6TjsLZ8dUkMTlu6iO85pyx)                 ===> [1] 1  1
# 0   | 269   | 17864 | 269   | Downloading Albums For Maureen Brathwaite (5By6yQX7NoDjSwTfWZRtOy)          ===> [4] 4  4
# 0   | 270   | 17864 | 270   | Downloading Albums For Mariana Grace (69iIE2NtvOKaLIU1TfyOPq)               ===> [1] 1  1
# 0   | 271   | 17864 | 271   | Downloading Albums For Wiz 150 (7hCyN4csKexIi5totNWzfc)                     ===> [2] 2  2
# 0   | 272   | 17864 | 272   | Downloading Albums For Rosemary Winthrop (2khCWZGzYJ1Xln3NbSM4aa)           ===> [2] 2  2
# 0   | 273   | 17864 | 273   | Downloading Albums For Nathyn (19SDEnFYowy33AxsygTbXu)                      ===> [37] 37  37
# 0   | 274   | 17864 | 274   | Downloading Albums For Sailor Guardian (2BIlUI0iPhjS6vqHCysGth)             ===> [1] 1  1
# 0   | 275   | 17864 | 275   | Downloading Albums For MC Vitorioso (5g6tpMTC3U9sA29yMJ2oGJ)                ===> [1] 1  1
# 0   | 276   | 17864 | 276   | Downloading Albums For West Side Piru (77ASkwMrT7UfkN8zzjDivr)              ===> [1] 1  1
# 0   | 299   | 17864 | 299   | Downloading Albums For Laurence Dreyfus (6Yd3XlB4TaT1BqxvjCH44t)            ===> [6] 6  6
#  [Getting Spotify ArtistIDs] | 300/?      : RunTime 14 Minute and 50 Second.
# ****************************************************************************************************************************
# *                                                Saving DownloadArtistAlbum                                                *
# ****************************************************************************************************************************
#   Saving Index [2435591] ... Done
#   Saving Error [55] ... Done
# Waiting:   0%|          | 0/150 [00:00<?, ?it/s]
# 0   | 300   | 17864 | 300   | Downloading Albums For Soumik Sen (1kwxW6jZABNOXKm0ftVUGj)                  ===> [2] 2  2
# 0   | 301   | 17864 | 301   | Downloading Albums For Cole Calico (57eFBbfUJqd6VzrGCNGVpP)                 ===> [3] 3  3
# 0   | 302   | 17864 | 302   | Downloading Albums For MEGTARO (3o3JLHE1KQzNc2wh46UiNI)                     ===> [4] 4  4
# 0   | 303   | 17864 | 303   | Downloading Albums For Memo ATR (6V1DSqlrymaAFfZOOVNIDh)                    ===> [12] 12  12
# 0   | 304   | 17864 | 304   | Downloading Albums For James Allen (7wLBfPrAWCwJr7gNgGBsut)                 ===> [4] 4  4
# 0   | 305   | 17864 | 305   | Downloading Albums For Anja Reich (6qFghYQcetnX8P6lK1yu1L)                  ===> [1] 1  1
# 0   | 306   | 17864 | 306   | Downloading Albums For Ghost Fetish (4KcGdKUnJ9jwulLK0Ae7dj)                ===> [5] 5  5
# 0   | 307   | 17864 | 307   | Downloading Albums For SCRP (6mRmujco5e9ge5KHau1mV1)                        ===> [9] 9  9
# 0   | 308   | 17864 | 308   | Downloading Albums For Coolman (4mPp3KC3wnINariKLtJnCj)                     ===> [5] 5  5
# 0   | 309   | 17864 | 309   | Downloading Albums For Jay Valentino (1Cs4nzHbj00fQeqXM4dAlh)               ===> [12] 12  12
# 0   | 310   | 17864 | 310   | Downloading Albums For Marian (BR) (5FCqRgK9PqJYyfnBJg4AeH)                 ===> [9] 9  9
# 0   | 311   | 17864 | 311   | Downloading Albums For Jonny Lee (06ZMp76Mo2w54owV4hfiFu)                   ===> [2] 2  2
# 0   | 312   | 17864 | 312   | Downloading Albums For Yadah The Producer (1adBlcgWFuRfZAm9Cg3gsy)          ===> [4] 4  4
# 0   | 313   | 17864 | 313   | Downloading Albums For NoSleepCity (7opLwgKfKlk5QDmiL5BHYw)                 ===> [18] 18  18
# 0   | 314   | 17864 | 314   | Downloading Albums For Rohini (3rutJxzwm92FZSjKG4PJGX)                      ===> [63] 50  58
# 0   | 315   | 17864 | 315   | Downloading Albums For Jon Hubbard (66kkSguotOOi9v4oEVfAqO)                 ===> [1] 1  1
# 0   | 316   | 17864 | 316   | Downloading Albums For Big Charlie's Rubber Band (5JvjoB6JA0KoBjyEWnRq8C)   ===> [1] 1  1
# 0   | 317   | 17864 | 317   | Downloading Albums For Hubert Pettaway (6E0jpIzQ1uhMBu1deEpVvM)             ===> [1] 1  1
# 0   | 318   | 17864 | 318   | Downloading Albums For Delphia Montes (5uQ4iOwsrTDztn713RZvX9)              ===> [10] 10  10
# 0   | 899   | 17864 | 899   | Downloading Albums For ViCTOR (5hGglwNT9h2C3oU6cYvdUk)                      ===> [3] 3  3
#  [Getting Spotify ArtistIDs] | 900/?      : RunTime 46 Minute and 37 Second.
# ****************************************************************************************************************************
# *                                                Saving DownloadArtistAlbum                                                *
# ****************************************************************************************************************************
#   Saving Index [2436191] ... Done
#   Saving Error [55] ... Done
# Waiting:   0%|          | 0/150 [00:00<?, ?it/s]
# 0   | 900   | 17864 | 900   | Downloading Albums For DOT (5woyrAMdYnu7OEJ8WFbIv4)                         ===> [1] 1  1
# 0   | 901   | 17864 | 901   | Downloading Albums For Keisher Downie (6rzWI34uPtqLJh1LzZqNn8)              ===> [3] 3  3
# 0   | 902   | 17864 | 902   | Downloading Albums For Chapter (1o2ePpOEpr2D2Z7sv7lCt4)                     ===> [2] 2  2
# 0   | 903   | 17864 | 903   | Downloading Albums For Alicia Warns (6Qc2lM5TL7dlS0pMkceop5)                ===> [6] 6  6
# 0   | 904   | 17864 | 904   | Downloading Albums For Gunz N Dojaa (4UBXwFAdhLrw9Qre3XoeDQ)                ===> [10] 10  10
# 0   | 905   | 17864 | 905   | Downloading Albums For Roemisch (0WuIfBOsejzJRLHiVXtDSI)                    ===> [12] 12  12
# 0   | 906   | 17864 | 906   | Downloading Albums For Detective 47 (5asBoe7VTcJtdYlnROgjot)                ===> [4] 4  4
# 0   | 907   | 17864 | 907   | Downloading Albums For Mally (2ANK6d1QAml6VMLUlkcNJP)                       ===> [1] 1  1
# 0   | 908   | 17864 | 908   | Downloading Albums For Revelators (5ReSt4TOV38d0efd9BSRQl)                  ===> [1] 1  1
# 0   | 909   | 17864 | 909   | Downloading Albums For XRK (0Wtd1pAgn1nCYY7Ai1yc1I)                         ===> [6] 6  6
# 0   | 910   | 17864 | 910   | Downloading Albums For Mistah TZ (60nG597oQxZlDl0SF0yjVA)                   ===> [13] 13  13
# 0   | 911   | 17864 | 911   | Downloading Albums For Ízaro (4DvDWsPTKOGgqKDM54iCyD)                       ===> [1] 1  1
# 0   | 912   | 17864 | 912   | Downloading Albums For I.N.M.U.N.E. (29WByZYkpvuKbFTf2U1Ty6)                ===> [2] 2  2
# 0   | 913   | 17864 | 913   | Downloading Albums For Schwarzer Kaffee (7wSZSyKd3ij6h42y5XPxCz)            ===> [11] 11  11
# 0   | 914   | 17864 | 914   | Downloading Albums For The Kid (3uTJR4EGw1dp0X4ScPjQX6)                     ===> [2] 2  2
# 0   | 915   | 17864 | 915   | Downloading Albums For Tiger Lily (6r0BO4UuM5nRdpCp0tuKik)                  ===> [6] 6  6
# 0   | 916   | 17864 | 916   | Downloading Albums For Lil’Tiger (29ka2AhM6mazZ79lZvE6i8)                   ===> [1] 1  1
# 0   | 917   | 17864 | 917   | Downloading Albums For Young LS (0Av2VtOzpRndkujqegqyHU)                    ===> [8] 8  8
# 0   | 918   | 17864 | 918   | Downloading Albums For The Gun (7k1KuuInjpsD6S9xVpZ1BQ)                     ===> [1] 1  1
# 0   | 919   | 17864 | 919   | Downloading Albums For Tewodros Kassahun (3joaKgxwb4oCxJmq1UBl6M)           ===> [2] 2  2
# 0   | 920   | 17864 | 920   | Downloading Albums For Ayooscriv (5rZ5qdvjYLMLMMnzVrYwMe)                   ===> [1] 1  1
# 0   | 921   | 17864 | 921   | Downloading Albums For Narrator Cpt (3szIgXrJxvynl32eCvvKeJ)                ===> [1] 1  1
# 0   | 922   | 17864 | 922   | Downloading Albums For Gorkha Paul (4hUEQwoDOtNn7Py1TgV5jF)                 ===> [24] 24  24
# 0   | 923   | 17864 | 923   | Downloading Albums For Lee Reed (1u5zy08TEQOmBOcp39WWIF)                    ===> [24] 24  24
# 0   | 924   | 17864 | 924   | Downloading Albums For FATHER FROG (4gd4uT5iayzd0yAr1WGN3F)                 ===> [16] 16  16
# 0   | 925   | 17864 | 925   | Downloading Albums For BRG Beats (2kirVIa3bc4WWGXNcFA1ip)                   ===> [77] 50  77
# 0   | 926   | 17864 | 926   | Downloading Albums For JONGHYUN (3cN2OE9scLasbHW9N7KUsK)                    ===> [2] 2  2
# 0   | 927   | 17864 | 927   | Downloading Albums For Mabé (5f9NaEnpKWKxqsXJ8APOGO)                        ===> [5] 5  5
# 0   | 928   | 17864 | 928   | Downloading Albums For The Corners (5EVoaN0uvYPadzuqP0X2A2)                 ===> [2] 2  2
# 0   | 929   | 17864 | 929   | Downloading Albums For THF Omerta (3gCTfziUlLVbyFCOog37yw)                  ===> [3] 3  3
# 0   | 930   | 17864 | 930   | Downloading Albums For 鈴木茂 (4M8hU9eggTjy9Ds3xf2dUS)                         ===> [1] 1  1
# 0   | 931   | 17864 | 931   | Downloading Albums For Goa Trance Doc (4AC948uNT6WoUf74ftydM2)              ===> [2] 2  2
# 0   | 932   | 17864 | 932   | Downloading Albums For Stay On The Beat (7kmCfl0dNk8FG48EL3mmuq)            ===> [7] 7  7
# 0   | 933   | 17864 | 933   | Downloading Albums For Le Ombre Verdi (2SHpv7sBq17Q34lziLNxyh)              ===> [1] 1  1
# 0   | 934   | 17864 | 934   | Downloading Albums For GuidoMartins (0CoErNQ0pipJ6kbqzPWFCI)                ===> [22] 22  22
# 0   | 935   | 17864 | 935   | Downloading Albums For RIP TXNY (42Vpgueugodd6ST0o6F57P)                    ===> [20] 20  20
# 0   | 936   | 17864 | 936   | Downloading Albums For Swill (4ZSaqYP5yHbkelqbNAdMxm)                       ===> [4] 4  4
# 0   | 937   | 17864 | 937   | Downloading Albums For RIPAPRIL (4CeddUvdY6pYk1JoOa9YZl)                    ===> [2] 2  2
# 0   | 938   | 17864 | 938   | Downloading Albums For Tato Rap (7pijVlkMhzTbM1V0xa6I62)                    ===> [24] 24  24
# 0   | 939   | 17864 | 939   | Downloading Albums For Bha Onkar Singh Dyalpur (5A4IRcV40Ay4H28DMZCCBh)     ===> [1] 1  1
# 0   | 940   | 17864 | 940   | Downloading Albums For Deathtrip Armada (49q82cS9aoEPiqaC4QGrqc)            ===> [1] 1  1
# 0   | 963   | 17864 | 963   | Downloading Albums For Lucky Devils (7k2Y7waLwIrZFF7l19nEKh)                ===> [3] 3  3
# 0   | 964   | 17864 | 964   | Downloading Albums For Kingsley Peiris (1iMHt6p9Zt0Y1b5DSIylGs)             ===> [2] 2  2
# 0   | 965   | 17864 | 965   | Downloading Albums For Guise (269LHlEwmrcUtGHVDV6eQs)                       ===> [8] 8  8
# 0   | 966   | 17864 | 966   | Downloading Albums For Blue Diary (4hnwRVwtUL8wOmotdLRrw0)                  ===> [16] 16  16
# 0   | 967   | 17864 | 967   | Downloading Albums For Man An Ocean (6SJ2SYsA1wy9xrEHgebvtQ)                ===> [3] 3  3
# 0   | 968   | 17864 | 968   | Downloading Albums For Nestor Trevino (68pHuQNKLrmOte6cLeNkeB)              ===> [1] 1  1
# 0   | 969   | 17864 | 969   | Downloading Albums For TFT - The Fellow Traveller feat. Reagan James (5dY2Yk6z8LIewXwWckBSx2)   ===> [1] 1  1
# 0   | 970   | 17864 | 970   | Downloading Albums For Aaron Racer (57AKXfsBkc98BTxk3sKc9z)                 ===> [9] 9  9
# 0   | 971   | 17864 | 971   | Downloading Albums For Vintage Magix (4hhRh1zNPo5PeEUrvvQSCQ)               ===> [20] 20  20
# 0   | 972   | 17864 | 972   | Downloading Albums For KpriBTC (7D0qOkJQLtbh45qiCHgftJ)                     ===> [12] 12  12
# 0   | 973   | 17864 | 973   | Downloading Albums For Lil Kate (7dWaS1H68mcZlRnVqRXTKs)                    ===> [1] 1  1
# 0   | 974   | 17864 | 974   | Downloading Albums For States Of Flux (55NL6M0RDmVyqoolAOMKEu)              ===> [1] 1  1
# 0   | 975   | 17864 | 975   | Downloading Albums For Bobby Kane (3CONlEdelaWwGT7xbUQYke)                  ===> [30] 30  30
# 0   | 976   | 17864 | 976   | Downloading Albums For Moogmatik (3yqaEkKbomMlRnUmCaL6B6)                   ===> [1] 1  1
# 0   | 977   | 17864 | 977   | Downloading Albums For Dream Hole Digger (52mg3RJWTPg8ZGgDUb1Z3p)           ===> [1] 1  1
# 0   | 978   | 17864 | 978   | Downloading Albums For Luvial Dreams (4EQk4ac7CLi3AcuSFDehDH)               ===> [1] 1  1
# 0   | 979   | 17864 | 979   | Downloading Albums For Woahkeii (0pVKsgpZbpJA3v3aEKFj6L)                    ===> [8] 8  8
# 0   | 980   | 17864 | 980   | Downloading Albums For K.E.FEAR feat. Rusty (55gtbbkldl4TWJfAwVzXJA)        ===> [1] 1  1
# 0   | 981   | 17864 | 981   | Downloading Albums For SLAVCHEG (7JMZ3DhJhKhkm9Xoy0Wujj)                    ===> [21] 21  21
# 0   | 982   | 17864 | 982   | Downloading Albums For Aurélio Leyton (4jMGL81sBzTJEIshZ13EcH)              ===> [0] 0  0
# 0   | 983   | 17864 | 983   | Downloading Albums For Cat Boy Sound (2kydCXLkEWpjsjZHkWEt3T)               ===> [51] 50  50
# 0   | 984   | 17864 | 984   | Downloading Albums For CHARLIE (0m7Dqf1y6oNFWE1MItYfVA)                     ===> [4] 4  4
# 0   | 985   | 17864 | 985   | Downloading Albums For ZhiBae (1G4NdlvnNOs23eUpIGW17b)                      ===> [1] 1  1
# 0   | 986   | 17864 | 986   | Downloading Albums For Sangue X Ódio Hardcore (5wv9ACqf8KSOpRJ2x1Z9Wq)      ===> [1] 1  1
# 0   | 987   | 17864 | 987   | Downloading Albums For La Más Brillante Banda El Tesoro De Michoacan (2GWEpgSMG6nbF3eBvzVFfu)   ===> [6] 6  6
# 0   | 988   | 17864 | 988   | Downloading Albums For Luyah路雅 (2v5zHkJIKX1eoB5VkaAI2z)                     ===> [1] 1  1
# 0   | 989   | 17864 | 989   | Downloading Albums For Stic Man (2mOarova5E5PoOXqURaESy)                    ===> [1] 1  1
# 0   | 990   | 17864 | 990   | Downloading Albums For L00ney L00n (4Hfux4JrAoCHgzGbvtr02w)                 ===> [14] 14  14
# 0   | 991   | 17864 | 991   | Downloading Albums For Soraia & Manu (1tGwwqjCHjPOaQAMrfPo8K)               ===> [1] 1  1
# 0   | 992   | 17864 | 992   | Downloading Albums For Pilots Of Peace (40ZKpcyktcFEoObFiyFgDv)             ===> [2] 2  2
# 0   | 993   | 17864 | 993   | Downloading Albums For Kvarteto zobcových fléten Miloslava Klementa (2xcUNCowoUGJqF4YuxKpOT)   ===> [1] 1  1
# 0   | 994   | 17864 | 994   | Downloading Albums For irma! (1r0egdckgcMXblZdNjgqjJ)                       ===> [9] 9  9
# 0   | 995   | 17864 | 995   | Downloading Albums For Lari Friedman (4YZf44xS51B83lzfVhqiOv)               ===> [1] 1  1
# 0   | 996   | 17864 | 996   | Downloading Albums For JL El Oráculo (0tMfgW2i9O2aekH8gLSX5y)               ===> [1] 1  1
# 0   | 997   | 17864 | 997   | Downloading Albums For Peggy Cadeaux (0YykaRSjbf5bkYp3mKZsvC)               ===> [1] 1  1
# 0   | 998   | 17864 | 998   | Downloading Albums For Cindy Sanchez (6iue1lqjkg0VvNRky04Zly)               ===> [2] 2  2
# 0   | 999   | 17864 | 999   | Downloading Albums For Laurie Adams-Klein (1TGiquCqKFlAUHLZNNfOZt)          ===> [1] 1  1
#  [Getting Spotify ArtistIDs] | 1000/?     : RunTime 51 Minute and 44 Second.
# ****************************************************************************************************************************
# *                                                Saving DownloadArtistAlbum                                                *
# ****************************************************************************************************************************
#   Saving Index [2436291] ... Done
#   Saving Error [55] ... Done
# Waiting:   0%|          | 0/150 [00:00<?, ?it/s]
# 0   | 1000  | 17864 | 1000  | Downloading Albums For KonigTiger (63WgRXpbHInHdd2RlROUYZ)                  ===> [1] 1  1
# 0   | 1001  | 17864 | 1001  | Downloading Albums For Facundo Oliva (6AqTnsuuy3YKr4QIS4wnbj)               ===> [4] 4  4
# 0   | 1002  | 17864 | 1002  | Downloading Albums For Wolfy (0OYGG0jvebVffo85igvaZR)                       ===> [2] 2  2
# 0   | 1003  | 17864 | 1003  | Downloading Albums For Yuto Wonderful (28L2sIWNr2GaHr6BxsBEWR)              ===> [3] 3  3
# 0   | 1004  | 17864 | 1004  | Downloading Albums For Alex Dawa (6btZeIxzYQSnzutRBcyUlV)                   ===> [6] 6  6
# 0   | 1005  | 17864 | 1005  | Downloading Albums For The Soul Symphony (5qLJ3GSTv7SckKWz1BsJc8)           ===> [1] 1  1
# 0   | 1006  | 17864 | 1006  | Downloading Albums For Boyoboy (71x8FDQfOvVbv59K3VMoKc)                     ===> [6] 6  6
# 0   | 1007  | 17864 | 1007  | Downloading Albums For Jamil Honesty (3fZ4vrFZoxJIFCGunIqxIZ)               ===> [1] 1  1
# 0   | 1008  | 17864 | 1008  | Downloading Albums For Itta Alpar (3T5XYhMVglqjDDo9pYsgLu)                  ===> [2] 2  2
# 0   | 1009  | 17864 | 1009  | Downloading Albums For Marcos Gonzalez MGH (0cC5uIdlohtl7w0T2C0oL2)         ===> [1] 1  1
# 0   | 1010  | 17864 | 1010  | Downloading Albums For Lautaro Rissone (5qUTdoNpEzb1opTKAAW7AL)             ===> [1] 1  1
# 0   | 1011  | 17864 | 1011  | Downloading Albums For Saki (0MprbbZ7k8p9ecQBaBj6E4)                        ===> [16] 16  16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 46
#      44 dbio.rdio.saveData("RawArtistAlbum", modVal, artistID, data=response)
#      45 downloadArtistAlbumRecord.setIndex(index=artistID)
# ---> 46 apiio.sleep(2.5)
#      47 n += 1
#      49 if n % 5 == 0:
#
# File ~/code/utils/src/utils/webutil.py:10, in sleep(value)
#       9 def sleep(value):
# ---> 10     time.sleep(value)
#
# KeyboardInterrupt:

# %%
downloadArtistAlbumRecord.save()
# Out:
# ****************************************************************************************************************************
# *                                                Saving DownloadArtistAlbum                                                *
# ****************************************************************************************************************************
#   Saving Index [2436303] ... Done
#   Saving Error [55] ... Done

# %% [markdown]
# # Download Album Data

# %% [markdown]
# ## Create Media Data

# %%
mediaData = {}
for modVal in range(100):
    modValData = dbio.data.getModValData(modVal)
    modValMediaData = {}
    for artistID,artistIDData in modValData.iteritems():
        for mediaType,mediaTypeData in artistIDData.media.media.items():
            modValMediaData.update({code: [artistID,media.album,media.url] for code,media in mediaTypeData.items()})
    mediaData.update(modValMediaData)
    if (modVal+1) % 10 == 0:
        print(f"ModVal = {modVal+1}")
        
df = DataFrame(mediaData).T
df.columns = ["ArtistID", "Name", "Ref"]
knownMedia.save(data=df)

# %% [markdown]
# ## Download Data

# %%
dbio   = bandcamp.MusicDBIO(verbose=False,local=True,mkDirs=False)
apiio = bandcamp.RawAPIData(debug=False)

# %%
useArtist = False
numMaster = 250

knownAlbumsData = knownMedia.get()
knownAlbumsData['IndexModVal'] = knownAlbumsData.index.map(dbio.getModVal)
availableNames  = concat([artistIDDF.head(numMaster) for artistID,artistIDDF in knownAlbumsData.groupby(["ArtistID"])])
localAlbumsDict = localAlbums.get()
availableNames  = availableNames[~availableNames.index.isin(localAlbumsDict.keys())]
albumNamesToGet = Series({modVal: modValDF for modVal,modValDF in availableNames.groupby(["IndexModVal"])})

print(f"# {db} Album Search Results")
print(f"#   Available Album IDs:  {knownAlbumsData.shape[0]}")
print(f"#   Known Album IDs:      {len(localAlbumsDict)}")
print(f"#   Albums To Download:   {availableNames.shape[0]}")

del availableNames
del localAlbumsDict
del knownAlbumsData

#   Albums To Download:   23457
#   Albums To Download:   20437
#   Albums To Download:   12137
#   Albums To Download:   4132

# %%
def saveAlbumData(db, localAlbumsDict, searchedForErrors):
    print("="*150)
    print(f"Saving {len(localAlbumsDict)} {db} Albums Data")
    localAlbums.save(data=localAlbumsDict)
    print(f"Saving {len(searchedForErrors)} {db} Searched For Errors")
    errors.save(data=searchedForErrors)
    print("="*150)

# %%
ts = Timestat("Getting {0} AlbumIDs".format(db))
tt = getTT(skipEOD=False)

n    = 0
maxN = 25000000
localAlbumsDict     = localAlbums.get()
searchedForErrors   = errors.get()
stop = False
nErrors = []
for groupModVal,modValData in albumNamesToGet.iteritems():
    if stop is True:
        break
    for j,(albumID,row) in enumerate(modValData.iterrows()):
        if len(nErrors) >= 5:
            for artistID in nErrors:
                print(f"del searchedForErrors['{artistID}']")
                stop=True
                break
        if any([dct.get(albumID) is not None for dct in [localAlbumsDict, searchedForErrors]]):
            continue
            
        artistID   = row["ArtistID"]
        albumName  = row["Name"]
        albumRef  = row["Ref"]

        print(f"{groupModVal: <8} |{j: <8} | {n: <8} | ", end="")
        try:
            response = apiio.getAlbumData(albumName=albumName, albumRef=albumRef)
        except:
            print("Error ==> {0}".format(albumName))
            searchedForErrors[albumID] = True
            nErrors.append(albumID)
            apiio.sleep(10)
            continue

        if not isinstance(response,bytes):
            print("Error ==> {0}".format(albumName))
            searchedForErrors[albumID] = True
            nErrors.append(albumID)
            apiio.sleep(3.5)
            continue

        nErrors = []
        modVal=dbio.mv.get(albumID)
        dbio.data.saveRawArtistAlbumData(data=response, modval=modVal, dbID=albumID)
        localAlbumsDict[albumID] = True
        apiio.sleep(4.5)
        n += 1
        nLastErrors = 0
        
        if n % 5 == 0:
            if tt.isFinished():
                stop=True
                break

        if n % 50 == 0:
            apiio.sleep(5)
            
        if n % 100 == 0:
            saveAlbumData(db, localAlbumsDict, searchedForErrors)
            if tt.isFinished():
                stop=True
                break
            apiio.wait(10.0)

        if n >= maxN:
            print("Breaking after {0} downloads...".format(maxN))
            stop=True
            break

ts.stop()
if True: saveAlbumData(db, localAlbumsDict, searchedForErrors)

# %%
from os import getpid
getpid()

# %% [markdown]
# # Download Lists

# %% [markdown]
# ## Download Starter

# %%
from apiutils import apiio
from ioutils import FileIO, HTMLIO
io  = FileIO()
hio = HTMLIO()
apiio = apiio()

# %%
starter             = {}
starter["List"]     = "https://www.bandcamp.org/lists.php"
starter["Genre"]    = "https://www.bandcamp.org/genre.php"
#starterBestAlbum = "https://www.bandcamp.org/ratings/6-highest-rated/2023/1"
starter["Rating"]   = "https://www.bandcamp.org/ratings"
starter["Discover"] = "https://www.bandcamp.org/discover"
starter["Releases"] = "https://www.bandcamp.org/releases"
starter["MustHear"] = "https://www.bandcamp.org/must-hear"

savename = "../../sandbox/AOTYstarter.p"
starterData = io.get(savename)
for key,url in starter.items():
    if starterData.get(key) is not None:
        continue
    retval = apiio.get(url)
    if retval.code == 200:
        print(key)
        starterData[key] = retval.data
    apiio.sleep(3)
        
print(f"Saving data to {savename}")
io.save(idata=starterData, ifile=savename)

# %%
useStarter = False
useSite    = True

if useStarter is True:
    aotyData = io.get("../../sandbox/AOTYstarter.p")
elif useSite is True:
    aotyData = io.get("../../sandbox/AOTYsiteData.p") | io.get("../../sandbox/AOTYsiteData2.p")
else:
    aotyData = {}
    
N  = len(aotyData)
ts = Timestat(f"Sorting {N} Site Refs")
refsData = {"List": {}, "Lists": {}, "Rating": {}, "Album": {}, "Artist": {}, "Discover": {}, "Genre": {}, "MustHear": {}, "Release": {}, "Spotify": {}, "Apple": {}, "Amazon": {}, "User": {}}
for n,(key,keyData) in enumerate(aotyData.items()):
    if (n+1) % 500 == 0 or (n+1) == 100:
        ts.update(n=n+1, N=N)
        
    bsdata = hio.get(keyData)
    refs = bsdata.findAll("a")
    for ref in refs:
        href = ref.get('href')
        if not isinstance(href,str):
            continue
        if href.startswith("/list/"):
            refsData["List"][href] = ref.text.strip()
        elif "lists.php" in href:
            refsData["Lists"][href] = ref.text.strip()
        elif href.startswith("/ratings/"):
            refsData["Rating"][href] = ref.text.strip()
        elif href.startswith("/artist/"):
            refsData["Artist"][href] = ref.text.strip()
        elif href.startswith("/album/"):
            refsData["Album"][href] = ref.text.strip()
        elif href.startswith("/discover/"):
            refsData["Discover"][href] = ref.text.strip()
        elif href.startswith("/genre/"):
            refsData["Genre"][href] = ref.text.strip()
        elif href.startswith("/must-hear/"):
            refsData["MustHear"][href] = ref.text.strip()
        elif "/releases/" in href:
            refsData["Release"][href] = ref.text.strip()
        elif "spotify.com" in href:
            refsData["Spotify"][href] = ref.text.strip()
        elif "apple.com" in href:
            refsData["Apple"][href] = ref.text.strip()
        elif "amazon.com" in href:
            refsData["Amazon"][href] = ref.text.strip()
        elif "/user/" in href:
            refsData["User"][href] = ref.text.strip()
        else:
            continue
            print(href,'\t|\t',ref.text)
            
ts.stop()

# %%
savename = "../../sandbox/AOTYsiteRefs.p"
print(f"Saving data to {savename}")
for key,keyData in refsData.items():
    print(f"  {key: <20}{len(keyData)}")
io.save(idata=refsData, ifile=savename)

# %%
siteData   = {}
artistData = {}
albumData  = {}
userData   = {}
otherData  = {}

if False:
    for ref,name in refsData["List"].items():
        if ref.startswith("/artist/"):
            artistData[ref] = name
        elif ref.startswith("/album/"):
            albumData[ref] = name
        elif ref.startswith("/user/"):
            userData[ref] = name
        elif ref.startswith("/"):
            siteData[ref] = name
        else:
            otherData[ref] = name
else:
    for key,keyData in refsData.items():
        for ref,name in keyData.items():
            if ref.startswith("/artist/"):
                artistData[ref] = name
            elif ref.startswith("/album/"):
                albumData[ref] = name
            elif ref.startswith("/user/"):
                userData[ref] = name
            elif ref.startswith("/"):
                if "/list/" in ref:
                    siteData[ref] = name
                else:
                    otherData[ref] = name
            else:
                otherData[ref] = name
            
print(f"Found {len(artistData)} Artist Refs")
print(f"Found {len(albumData)} Album Refs")
print(f"Found {len(userData)} User Refs")
print(f"Found {len(siteData)} Site Refs")
print(f"Found {len(otherData)} Other Refs")

# %%
for year in range(1970,2005):
    key = f'/lists.php?y={year}'
    val = 'View More'
    siteData[key] = val

# %%
savename1 = "../../sandbox/AOTYsiteData.p"
siteDataDownloads1 = io.get(savename1)
print(f"Found {len(siteDataDownloads1)} Previous Downloads")
savename2 = "../../sandbox/AOTYsiteData2.p"
siteDataDownloads2 = io.get(savename2)
print(f"Found {len(siteDataDownloads2)} Previous Downloads")
N = len(siteData)
ts = Timestat(f"Downloading {N} Site Refs")
for n,(ref,name) in enumerate(siteData.items()):
    url=f"https://www.bandcamp.org{ref}"
    if any([dct.get(ref) is not None for dct in [siteDataDownloads1,siteDataDownloads2]]):
        continue
    
    retval = apiio.get(url)
    if retval.code == 200:
        print(f"{n: <6} | {N: <6} | {ref}")
        siteDataDownloads2[ref] = retval.data
    apiio.sleep(3)
    
    if (n+1) % 25 == 0:
        ts.update(n=n+1,N=N)
        print(f"Saving {len(siteDataDownloads2)} data to {savename2}")
        io.save(idata=siteDataDownloads2, ifile=savename2)

ts.stop()
        
print(f"Saving data to {savename2}")
io.save(idata=siteDataDownloads2, ifile=savename2)

# %%
siteDataDownloads = io.get("../../sandbox/AOTYsiteData.p")

# %%
io.save(idata=siteDataDownloads, ifile=savename)

# %% [markdown]
# ## Check For New Data

# %%
from lib.bandcamp import MusicDBID
mid = MusicDBID()
mid.getAlbumID('/album/515536-beyonce-renaissance/critic-lists/?f=all&y=2022')

# %%
df = DataFrame(Series(refsData["Album"])).reset_index().rename(columns={"index": "Ref", 0: "List"})
df["AlbumID"] = df["Ref"].map(mid.getAlbumID)
df = df[~df["AlbumID"].duplicated()]

# %%
df = DataFrame(Series(refsData["Artist"])).reset_index().rename(columns={"index": "Ref", 0: "Name"})
df["ArtistID"] = df["Ref"].map(mid.getArtistID)
df = df[~df["ArtistID"].duplicated()]

# %%
artistNames = searchArtists()

# %%
df.index = df["ArtistID"]
df = df.drop(["ArtistID"], axis=1)
artistNames = concat([artistNames,df])
artistNames = artistNames[~artistNames.index.duplicated()]

# %%
dbio.data.saveSearchArtistData(data=artistNames)

# %% [markdown]
# # Backup

# %%
from utils import StoreData, backup
from numpy import array_split
sd = StoreData("bandcamp", "Artist")
for modVals in array_split(range(100), 2):
    sd.mergeLocalData(modVals=modVals)
sd.mergeGlobalData()

# %%
from time import sleep
sleep(200)
sd.mergeGlobalData()

# %%
for modVal in range(67):
    srcDir = DirInfo(f"/Volumes/Piggy/Discog/artists-bandcamp/{modVal}/artists")
    files  = [FileInfo(ifile) for ifile in srcDir.getFiles()]
    files  = [finfo for finfo in files if finfo.basename.isdigit()]
    dstDir = DirInfo(f"/Users/tgadfort/Music/Discog/artists-bandcamp/{modVal}/artists")
    for srcFile in files:
        dstFile = dstDir.join(srcFile.name)
        srcFile.mvFile(dstFile)
